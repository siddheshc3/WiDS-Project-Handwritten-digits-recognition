# %% [markdown]
# <a href="https://colab.research.google.com/github/siddheshc3/WiDS-Project-Handwritten-digits-recognition/blob/main/WiDS_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np 
import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow import keras 

#tfds.disable_progress_bar()

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize the data
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# Build the model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10)

# Evaluate the model
val_loss, val_acc = model.evaluate(x_test, y_test)
print(f'Test loss: {val_loss}, Test accuracy: {val_acc}')

# Save the model
model.save('mnist_model.WiDS_Project')
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2615 - accuracy: 0.9220
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1069 - accuracy: 0.9676
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0726 - accuracy: 0.9771
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0536 - accuracy: 0.9827
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0411 - accuracy: 0.9863
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0327 - accuracy: 0.9890
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0245 - accuracy: 0.9918
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0222 - accuracy: 0.9920
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0177 - accuracy: 0.9942
# Epoch 10/10
# ...

# %% [markdown]
# For the prediction of digit in any general image, which is uploaded into the code in its runtime:

# %%
# Load the trained model
model = tf.keras.models.load_model('mnist_model.WiDS_Project')

# Load an image to predict
#new_image = plt.imread('C:\Users\Siddhesh\Desktop\1.jpg')

from google.colab import files
from PIL import Image

# Upload the image file
uploaded = files.upload()

# Get the file name of the uploaded file
for name, data in uploaded.items():
    file_name = name

# Open the uploaded image
with Image.open(file_name) as im:
    # Resize the image to 28x28 pixels
    im = im.resize((28, 28))
    # Convert the image to grayscale
    im = im.convert('L')
    # Convert the image to a numpy array
    new_image = np.array(im)


# Preprocess the image
new_image = tf.keras.utils.normalize(new_image, axis=1)
new_image = np.expand_dims(new_image, axis=0)

# Make a prediction
prediction = model.predict(new_image)

# Get the index of the highest prediction
predicted_digit = np.argmax(prediction)

print(f'Predicted digit: {predicted_digit}')
# Out:
#      <input type="file" id="files-a2f1c2f0-0224-4956-a153-269801a3585e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a2f1c2f0-0224-4956-a153-269801a3585e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
